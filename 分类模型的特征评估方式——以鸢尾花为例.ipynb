# %%
# 导入基本包
import numpy as np
import pandas as pd
from pandas import Series,DataFrame

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
# 导入数据
from sklearn.datasets import load_iris

# %%
iris = load_iris()

# %%
data = iris.data
target = iris.target
feaure_names = iris.feature_names
target_names = iris.target_names

# %%
df = DataFrame(data=data,columns=feaure_names)
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
# 把数据按照不同的标签划分为3个子类
class1 = df.iloc[target == 0]
class2 = df.iloc[target == 1]
class3 = df.iloc[target == 2]

# %%
for col_name in df.columns:
    data1 = class1[col_name]
    data2 = class2[col_name]
    data3 = class3[col_name]
    
    sns.distplot(data1, label="setosa")
    sns.distplot(data2, label="versicolor")
    sns.distplot(data3, label="virginica")
    plt.legend()
    plt.show()

# %%
# 发现第二列数据分布较为接近，所以对分类就会有干扰，不利于分类模型

# %%
df.columns.values
# Out:
# array(['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
#        'petal width (cm)'], dtype=object)

# %%
# 以第一列和第二列来看鸢尾花的二维分布图
plt.scatter(df["sepal length (cm)"],df["sepal width (cm)"],c=target)

# %%
# 以第三列和第四列来看鸢尾花的二维分布图
plt.scatter(df["petal length (cm)"],df["petal width (cm)"],c=target)

# %%
'''
线性回归重点内容回顾：
1、算法 y = wx + b
2、VSM 二维表格
X = （x1， x2， x3，x4）
W = （w1， w2， w3， w4）
y = W*X + b
W需要转秩
shape m，n
shape k，o

3、最小二乘法  损失函数 h（w）=（y-y’）**2.sum（）
   目标函数：对损失函数求全局最小值时对应的W值，h（w）求导==0
4、线性回归：必然是一条直线，容易欠拟合，只擅长解决符合线性分布数据集；效率极高
5、特征选择：线性回归模型来评估特征的重要性，查看每个特征和目标建模之后的w系数
            分类模型  观察不同类别相同数据的直方图分布来查看关系

'''
